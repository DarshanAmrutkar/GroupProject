# %% [markdown]
# | 4/27/23, 9:45 PM | DL4_B213021_GoogleStock.ipynb - Colaboratory |
# |------------------|----------------------------------------------|
#
# |     |
# |-----|
#
# > import numpy as np \# linear algebra
# > import pandas as pd \# data processing, CSV file I/O (e.g.
# > pd.read_csv)
# > import matplotlib.pyplot as plt
# >
# > \# Input data files are available in the "../input/" directory.
# >
# > \# For example, running this (by clicking run or pressing Shift+Enter)
# > will list the files in the input directory
# >
# > import os
# > print(os.listdir("../input"))
# >
# > \# Any results you write to the current directory are saved as output.
# >
# > \['testset.csv', 'trainset.csv'\]
# >
# > dataset_train = pd.read_csv("../input/trainset.csv")
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th colspan="2"><blockquote>
# <p>dataset_train</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td>https://colab.research.google.com/drive/1vNpD80L3kJ6r1xGYeyYTMS2hItp4ZvIc</td>
# <td>1/7</td>
# </tr>
# </tbody>
# </table>
#
# <img
# src="attachment:vertopal_9c25606b7988456e932b5da7ae04e8c9/media/image1.png"
# style="width:4.52778in;height:5.83333in" />
#
# <table>
# <colgroup>
# <col style="width: 12%" />
# <col style="width: 12%" />
# <col style="width: 12%" />
# <col style="width: 12%" />
# <col style="width: 12%" />
# <col style="width: 12%" />
# <col style="width: 12%" />
# <col style="width: 12%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th colspan="4">4/27/23, 9:45 PM</th>
# <th rowspan="2"><strong>Low</strong></th>
# <th colspan="3"><blockquote>
# <p>DL4_B213021_GoogleStock.ipynb - Colaboratory</p>
# </blockquote></th>
# </tr>
# <tr class="odd">
# <th colspan="2"><strong>Date</strong></th>
# <th><strong>Open</strong></th>
# <th><strong>High</strong></th>
# <th><strong>Close</strong></th>
# <th><blockquote>
# <p><strong>Adj Close</strong></p>
# </blockquote></th>
# <th><blockquote>
# <p><strong>Volum</strong></p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td rowspan="2"><strong>0</strong></td>
# <td>2013-</td>
# <td rowspan="2"><blockquote>
# <p>357.385559</p>
# </blockquote></td>
# <td rowspan="2">361.151062</td>
# <td rowspan="2">355.959839</td>
# <td rowspan="2">359.288177</td>
# <td rowspan="2">359.288177</td>
# <td rowspan="2"><blockquote>
# <p>511550</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td>01-02</td>
# </tr>
# <tr class="odd">
# <td rowspan="2"><strong>1</strong></td>
# <td>2013-</td>
# <td rowspan="2"><blockquote>
# <p>360.122742</p>
# </blockquote></td>
# <td rowspan="2">363.600128</td>
# <td rowspan="2">358.031342</td>
# <td rowspan="2">359.496826</td>
# <td rowspan="2">359.496826</td>
# <td rowspan="2"><blockquote>
# <p>466650</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td>01-03</td>
# </tr>
# <tr class="odd">
# <td rowspan="2"><strong>2</strong></td>
# <td>2013-</td>
# <td rowspan="2"><blockquote>
# <p>362.313507</p>
# </blockquote></td>
# <td rowspan="2">368.339294</td>
# <td rowspan="2">361.488861</td>
# <td rowspan="2">366.600616</td>
# <td rowspan="2">366.600616</td>
# <td rowspan="2"><blockquote>
# <p>556280</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td>01-04</td>
# </tr>
# <tr class="odd">
# <td rowspan="2"><strong>3</strong></td>
# <td>2013-</td>
# <td rowspan="2"><blockquote>
# <p>365.348755</p>
# </blockquote></td>
# <td rowspan="2">367.301056</td>
# <td rowspan="2">362.929504</td>
# <td rowspan="2">365.001007</td>
# <td rowspan="2">365.001007</td>
# <td rowspan="2"><blockquote>
# <p>333290</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td>01-07</td>
# </tr>
# <tr class="odd">
# <td rowspan="2"><strong>4</strong></td>
# <td>2013-</td>
# <td rowspan="2"><blockquote>
# <p>365.393463</p>
# </blockquote></td>
# <td rowspan="2">365.771027</td>
# <td rowspan="2">359.874359</td>
# <td rowspan="2">364.280701</td>
# <td rowspan="2">364.280701</td>
# <td rowspan="2"><blockquote>
# <p>337390</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td>01-08</td>
# </tr>
# <tr class="odd">
# <td rowspan="2"><strong>5</strong></td>
# <td>2013-</td>
# <td rowspan="2"><blockquote>
# <p>363.769043</p>
# </blockquote></td>
# <td rowspan="2">366.789398</td>
# <td rowspan="2">361.945892</td>
# <td rowspan="2">366.675140</td>
# <td rowspan="2">366.675140</td>
# <td rowspan="2"><blockquote>
# <p>407570</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td>01-09</td>
# </tr>
# <tr class="odd">
# <td rowspan="2"><strong>6</strong></td>
# <td>2013-</td>
# <td rowspan="2"><blockquote>
# <p>369.014923</p>
# </blockquote></td>
# <td rowspan="2">370.092896</td>
# <td rowspan="2">364.380066</td>
# <td rowspan="2">368.344269</td>
# <td rowspan="2">368.344269</td>
# <td rowspan="2"><blockquote>
# <p>369510</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td>01-10</td>
# </tr>
# <tr class="odd">
# <td rowspan="2"><strong>7</strong></td>
# <td>2013-</td>
# <td rowspan="2"><blockquote>
# <p>368.602600</p>
# </blockquote></td>
# <td rowspan="2">368.816193</td>
# <td rowspan="2">365.771027</td>
# <td rowspan="2">367.604095</td>
# <td rowspan="2">367.604095</td>
# <td rowspan="2"><blockquote>
# <p>258700</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td>01-11</td>
# </tr>
# <tr class="odd">
# <td rowspan="2"><strong>8</strong></td>
# <td>2013-</td>
# <td rowspan="2"><blockquote>
# <p>366.118744</p>
# </blockquote></td>
# <td rowspan="2">368.701935</td>
# <td rowspan="2">358.841095</td>
# <td rowspan="2">359.288177</td>
# <td rowspan="2">359.288177</td>
# <td rowspan="2"><blockquote>
# <p>576500</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td>01-14</td>
# </tr>
# <tr class="odd">
# <td rowspan="2"><strong>9</strong></td>
# <td>2013-</td>
# <td rowspan="2"><blockquote>
# <p>357.340851</p>
# </blockquote></td>
# <td rowspan="2">365.125214</td>
# <td rowspan="2">353.749207</td>
# <td rowspan="2">360.122742</td>
# <td rowspan="2">360.122742</td>
# <td rowspan="2"><blockquote>
# <p>790630</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td>01-15</td>
# </tr>
# <tr class="odd">
# <td rowspan="2"><strong>10</strong></td>
# <td>2013-</td>
# <td rowspan="2"><blockquote>
# <p>358.865936</p>
# </blockquote></td>
# <td rowspan="2">359.829651</td>
# <td rowspan="2">354.529144</td>
# <td rowspan="2">355.284210</td>
# <td rowspan="2">355.284210</td>
# <td rowspan="2"><blockquote>
# <p>407310</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td>01-16</td>
# </tr>
# <tr class="odd">
# <td rowspan="2"><strong>11</strong></td>
# <td>2013-</td>
# <td rowspan="2"><blockquote>
# <p>356.536072</p>
# </blockquote></td>
# <td rowspan="2">357.494843</td>
# <td rowspan="2">353.212677</td>
# <td rowspan="2">353.361725</td>
# <td rowspan="2">353.361725</td>
# <td rowspan="2"><blockquote>
# <p>445170</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td>01-17</td>
# </tr>
# <tr class="odd">
# <td rowspan="2"><strong>12</strong></td>
# <td>2013-</td>
# <td rowspan="2"><blockquote>
# <p>352.884827</p>
# </blockquote></td>
# <td rowspan="2">354.082031</td>
# <td rowspan="2">348.398987</td>
# <td rowspan="2">349.978729</td>
# <td rowspan="2">349.978729</td>
# <td rowspan="2"><blockquote>
# <p>649550</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td>01-18</td>
# </tr>
# <tr class="odd">
# <td rowspan="2"><strong>13</strong></td>
# <td>2013-</td>
# <td rowspan="2"><blockquote>
# <p>350.053253</p>
# </blockquote></td>
# <td rowspan="2">350.391052</td>
# <td rowspan="2">345.512787</td>
# <td rowspan="2">349.164032</td>
# <td rowspan="2">349.164032</td>
# <td rowspan="2"><blockquote>
# <p>763400</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td>01-22</td>
# </tr>
# <tr class="odd">
# <td rowspan="2"><strong>14</strong></td>
# <td>2013-</td>
# <td rowspan="2"><blockquote>
# <p>365.617004</p>
# </blockquote></td>
# <td rowspan="2">372.079987</td>
# <td rowspan="2">365.517670</td>
# <td rowspan="2">368.354218</td>
# <td rowspan="2">368.354218</td>
# <td rowspan="2"><blockquote>
# <p>1189500</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td>01-23</td>
# </tr>
# <tr class="odd">
# <td rowspan="2"><strong>15</strong></td>
# <td>2013-</td>
# <td rowspan="2"><blockquote>
# <p>368.225037</p>
# </blockquote></td>
# <td rowspan="2">375.969666</td>
# <td rowspan="2">367.862396</td>
# <td rowspan="2">374.668152</td>
# <td rowspan="2">374.668152</td>
# <td rowspan="2"><blockquote>
# <p>680920</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td>01-24</td>
# </tr>
# <tr class="odd">
# <td colspan="4"><p>2013-</p>
# <blockquote>
# <p><strong>16</strong> 372.959259 376.789337</p>
# <p>trainset = dataset_train.iloc[:,1:2].values 01-25</p>
# </blockquote></td>
# <td>372.700928</td>
# <td>374.399902</td>
# <td>374.399902</td>
# <td><blockquote>
# <p>448070</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td rowspan="2"><strong>17</strong></td>
# <td>2013-</td>
# <td rowspan="3"><blockquote>
# <p>373.451050</p>
# </blockquote></td>
# <td rowspan="3">375.358643</td>
# <td rowspan="2">371.528564</td>
# <td rowspan="2">372.939392</td>
# <td rowspan="2">372.939392</td>
# <td rowspan="2"><blockquote>
# <p>327530</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td rowspan="2">01-28</td>
# </tr>
# <tr class="even">
# <td>trainset</td>
# <td rowspan="4">370.857941</td>
# <td rowspan="4">374.404846</td>
# <td rowspan="4">374.404846</td>
# <td rowspan="4"><blockquote>
# <p>351680</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td colspan="3"><blockquote>
# <p>2013-<br />
# array([[ 357.385559], <strong>18</strong> 01-29 370.962250</p>
# </blockquote></td>
# <td>376.029297</td>
# </tr>
# <tr class="even">
# <td colspan="4">[ 360.122742],</td>
# </tr>
# <tr class="odd">
# <td colspan="4">[ 362.313507], 2013</td>
# </tr>
# </tbody>
# </table>
#
# > ...,
# > \[1057.390015\],
# > \[1051.599976\],
# > \[1046.719971\]\])
# >
# > from sklearn.preprocessing import MinMaxScaler
# > sc = MinMaxScaler(feature_range = (0,1))
# > training_scaled = sc.fit_transform(trainset)
# >
# > training_scaled
# >
# > array(\[\[0.01011148\],
# > \[0.01388614\],
# > \[0.01690727\],
# > ...,
# > \[0.97543954\],
# > \[0.9674549 \],
# > \[0.96072522\]\])
# >
# > x_train = \[\]
# > y_train = \[\]
# >
# > for i in range(60,1259):
# > x_train.append(training_scaled\[i-60:i, 0\])
# > y_train.append(training_scaled\[i,0\])
# > x_train,y_train = np.array(x_train),np.array(y_train)
#
# https://colab.research.google.com/drive/1vNpD80L3kJ6r1xGYeyYTMS2hItp4ZvIc
# 2/7
#
# 4/27/23, 9:45 PM DL4_B213021_GoogleStock.ipynb - Colaboratory
#
# > x_train.shape
# >
# > (1199, 60)
# >
# > x_train = np.reshape(x_train,
# > (x_train.shape\[0\],x_train.shape\[1\],1))
# >
# > from keras.models import Sequential
# > from keras.layers import Dense
# > from keras.layers import LSTM
# > from keras.layers import Dropout
# >
# > Using TensorFlow backend.
# >
# > regressor = Sequential()
# > regressor.add(LSTM(units = 50,return_sequences = True,input_shape =
# > (x_train.shape\[1\],1)))
# >
# > regressor.add(Dropout(0.2))
# >
# > regressor.add(LSTM(units = 50,return_sequences = True))
# > regressor.add(Dropout(0.2))
# >
# > regressor.add(LSTM(units = 50,return_sequences = True))
# > regressor.add(Dropout(0.2))
# >
# > regressor.add(LSTM(units = 50))
# > regressor.add(Dropout(0.2))
# >
# > regressor.add(Dense(units = 1))
# >
# > regressor.compile(optimizer = 'adam',loss = 'mean_squared_error')
# >
# > regressor.fit(x_train,y_train,epochs = 100, batch_size = 32)
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>Epoch 1/100<br />
# 1199/1199 [==============================] - 13s 11ms/step - loss:
# 0.0295 Epoch 2/100<br />
# 1199/1199 [==============================] - 9s 7ms/step - loss: 0.0054
# Epoch 3/100<br />
# 1199/1199 [==============================] - 9s 7ms/step - loss: 0.0038
# Epoch 4/100<br />
# 1199/1199 [==============================] - 9s 7ms/step - loss: 0.0040
# Epoch 5/100<br />
# 1199/1199 [==============================] - 9s 7ms/step - loss: 0.0037
# Epoch 6/100<br />
# 1199/1199 [==============================] - 9s 7ms/step - loss: 0.0032
# Epoch 7/100<br />
# 1199/1199 [==============================] - 9s 7ms/step - loss: 0.0035
# Epoch 8/100<br />
# 1199/1199 [==============================] - 9s 7ms/step - loss: 0.0033
# Epoch 9/100<br />
# 1199/1199 [==============================] - 9s 7ms/step - loss: 0.0034
# Epoch 10/100<br />
# 1199/1199 [==============================] - 9s 7ms/step - loss: 0.0029
# Epoch 11/100<br />
# 1199/1199 [==============================] - 9s 7ms/step - loss: 0.0032
# Epoch 12/100<br />
# 1199/1199 [==============================] - 9s 7ms/step - loss: 0.0028
# Epoch 13/100<br />
# 1199/1199 [==============================] - 9s 7ms/step - loss: 0.0030
# Epoch 14/100<br />
# 1199/1199 [==============================] - 9s 7ms/step - loss: 0.0029
# Epoch 15/100<br />
# 1199/1199 [==============================] - 9s 7ms/step - loss: 0.0029
# Epoch 16/100<br />
# 1199/1199 [==============================] - 9s 7ms/step - loss: 0.0026
# Epoch 17/100<br />
# 1199/1199 [==============================] - 9s 7ms/step - loss: 0.0025
# Epoch 18/100<br />
# 1199/1199 [==============================] - 9s 8ms/step - loss: 0.0028
# Epoch 19/100<br />
# 1199/1199 [==============================] - 9s 8ms/step - loss: 0.0023
# Epoch 20/100<br />
# 1199/1199 [==============================] - 9s 7ms/step - loss: 0.0025
# Epoch 21/100<br />
# 1199/1199 [==============================] - 9s 8ms/step - loss: 0.0025
# Epoch 22/100<br />
# 1199/1199 [==============================] - 9s 8ms/step - loss: 0.0024
# Epoch 23/100<br />
# 1199/1199 [==============================] - 9s 7ms/step - loss: 0.0022
# Epoch 24/100</p>
# </blockquote>
# <p>https://colab.research.google.com/drive/1vNpD80L3kJ6r1xGYeyYTMS2hItp4ZvIc</p></th>
# <th><p><img
# src="attachment:vertopal_9c25606b7988456e932b5da7ae04e8c9/media/image2.png"
# style="width:0.16667in;height:5.73611in" /></p>
# <p>3/7</p></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 33%" />
# <col style="width: 33%" />
# <col style="width: 33%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th>4/27/23, 9:45 PM</th>
# <th>DL4_B213021_GoogleStock.ipynb - Colaboratory</th>
# <th rowspan="2"><img
# src="attachment:vertopal_9c25606b7988456e932b5da7ae04e8c9/media/image3.png"
# style="width:0.16667in;height:1.43056in" /></th>
# </tr>
# <tr class="odd">
# <th colspan="2"><blockquote>
# <p>1199/1199 [==============================] - 9s 7ms/step - loss:
# 0.0023 Epoch 25/100<br />
# 1199/1199 [==============================] - 9s 7ms/step - loss: 0.0022
# Epoch 26/100<br />
# 1199/1199 [==============================] - 9s 8ms/step - loss: 0.0020
# Epoch 27/100<br />
# 1199/1199 [==============================] - 9s 7ms/step - loss: 0.0024
# Epoch 28/100<br />
# 1199/1199 [==============================] - 9s 7ms/step - loss: 0.0023
# Epoch 29/100<br />
# 1199/1199 [==============================] - 9s 7ms/step - loss:
# 0.0019</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > dataset_test =pd.read_csv("../input/testset.csv")
# >
# > real_stock_price = dataset_test.iloc\[:,1:2\].values
# >
# > dataset_total =
# > pd.concat((dataset_train\['Open'\],dataset_test\['Open'\]),axis = 0)
# > dataset_total
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>0 357.385559<br />
# 1 360.122742<br />
# 2 362.313507<br />
# 3 365.348755<br />
# 4 365.393463<br />
# 5 363.769043<br />
# 6 369.014923<br />
# 7 368.602600<br />
# 8 366.118744<br />
# 9 357.340851<br />
# 10 358.865936<br />
# 11 356.536072<br />
# 12 352.884827<br />
# 13 350.053253<br />
# 14 365.617004<br />
# 15 368.225037<br />
# 16 372.959259<br />
# 17 373.451050<br />
# 18 370.962250<br />
# 19 374.434662<br />
# 20 372.830109<br />
# 21 376.650238<br />
# 22 381.364594<br />
# 23 378.105774<br />
# 24 377.082428<br />
# 25 382.363098<br />
# 26 387.544403<br />
# 27 386.684998<br />
# 28 388.349152<br />
# 29 387.544403<br />
# ...</p>
# <p>95 1061.859985<br />
# 96 1074.060059<br />
# 97 1083.560059<br />
# 98 1065.130005<br />
# 99 1079.000000<br />
# 100 1079.020020<br />
# 101 1064.890015<br />
# 102 1063.030029<br />
# 103 1067.560059<br />
# 104 1099.349976<br />
# 105 1122.329956<br />
# 106 1140.989990<br />
# 107 1142.170044<br />
# 108 1131.319946<br />
# 109 1118.180054<br />
# 110 1118.599976<br />
# 111 1131.069946<br />
# 112 1141.119995<br />
# 113 1143.849976<br />
# 114 1148.859985<br />
# 115 1143.650024<br />
# 116 1158.500000<br />
# 117 1175.310059<br />
# 118 1174.849976<br />
# 119 1159.140015<br />
# 120 1143.599976<br />
# 121 1128.000000</p>
# </blockquote></th>
# <th><img
# src="attachment:vertopal_9c25606b7988456e932b5da7ae04e8c9/media/image4.png"
# style="width:0.16667in;height:7.08333in" /></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > inputs = dataset_total\[len(dataset_total) -
# > len(dataset_test)-60:\].values inputs
# >
# > array(\[ 955.48999 , 966.700012, 980. , 980. , 973.719971, 987.450012,
# > 992. , 992.099976, 990.289978, 991.77002 , 986. , 989.440002,
# > 989.52002 , 970. , 968.369995, 980. , 1009.190002, 1014. ,
# > 1015.219971, 1017.210022, 1021.76001 , 1022.109985, 1028.98999 ,
# > 1027.27002 , 1030.52002 , 1033.98999 , 1026.459961, 1023.419983,
# > 1022.590027, 1019.210022,
#
# https://colab.research.google.com/drive/1vNpD80L3kJ6r1xGYeyYTMS2hItp4ZvIc
# 4/7
#
# 4/27/23, 9:45 PM DL4_B213021_GoogleStock.ipynb - Colaboratory
#
# > 1022.52002 , 1034.01001 , 1020.26001 , 1023.309998, 1035. ,
# > 1035.869995, 1040. , 1055.089966, 1042.680054, 1022.369995,
# > 1015.799988, 1012.659973, 995.940002, 1001.5 , 1020.429993,
# > 1037.48999 , 1035.5 , 1039.630005, 1046.119995, 1045. ,
# > 1054.609985, 1066.079956, 1075.199951, 1071.780029, 1064.949951,
# > 1061.109985, 1058.069946, 1057.390015, 1051.599976, 1046.719971,
# > 1048.339966, 1064.310059, 1088. , 1094. , 1102.22998 ,
# > 1109.400024, 1097.099976, 1106.300049, 1102.410034, 1132.51001 ,
# > 1126.219971, 1131.410034, 1131.829956, 1137.48999 , 1159.849976,
# > 1177.329956, 1172.530029, 1175.079956, 1176.47998 , 1167.829956,
# > 1170.569946, 1162.609985, 1122. , 1090.599976, 1027.180054,
# > 1081.540039, 1055.410034, 1017.25 , 1048. , 1045. ,
# > 1048.949951, 1079.069946, 1088.410034, 1090.569946, 1106.469971,
# > 1116.189941, 1112.640015, 1127.800049, 1141.23999 , 1123.030029,
# > 1107.869995, 1053.079956, 1075.140015, 1099.219971, 1089.189941,
# > 1115.319946, 1136. , 1163.849976, 1170. , 1145.209961,
# > 1149.959961, 1154.140015, 1120.01001 , 1099. , 1092.73999 ,
# > 1081.880005, 1047.030029, 1046. , 1063. , 998. ,
# > 1011.630005, 1022.820007, 1013.909973, 993.409973, 1041.329956,
# > 1020. , 1016.799988, 1026.439941, 1027.98999 , 1025.040039,
# > 1040.880005, 1037. , 1051.369995, 1077.430054, 1069.400024,
# > 1082. , 1077.859985, 1052. , 1025.52002 , 1029.51001 ,
# > 1046. , 1030.01001 , 1013.659973, 1028.099976, 1019. ,
# > 1016.900024, 1049.22998 , 1058.540039, 1058.099976, 1086.030029,
# > 1093.599976, 1100. , 1090. , 1077.310059, 1079.890015,
# > 1061.859985, 1074.060059, 1083.560059, 1065.130005, 1079. ,
# > 1079.02002 , 1064.890015, 1063.030029, 1067.560059, 1099.349976,
# > 1122.329956, 1140.98999 , 1142.170044, 1131.319946, 1118.180054,
# > 1118.599976, 1131.069946, 1141.119995, 1143.849976, 1148.859985,
# > 1143.650024, 1158.5 , 1175.310059, 1174.849976, 1159.140015,
# > 1143.599976, 1128. , 1121.339966, 1102.089966, 1120. \])
# >
# > inputs = inputs.reshape(-1,1)
# >
# > inputs
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>array([[ 955.48999 ],<br />
# [ 966.700012],<br />
# [ 980. ],<br />
# [ 980. ],<br />
# [ 973.719971],<br />
# [ 987.450012],<br />
# [ 992. ],<br />
# [ 992.099976],<br />
# [ 990.289978],<br />
# [ 991.77002 ],<br />
# [ 986. ],<br />
# [ 989.440002],<br />
# [ 989.52002 ],<br />
# [ 970. ],<br />
# [ 968.369995],<br />
# [ 980. ],<br />
# [1009.190002],<br />
# [1014. ],<br />
# [1015.219971],<br />
# [1017.210022],<br />
# [1021.76001 ],<br />
# [1022.109985],<br />
# [1028.98999 ],<br />
# [1027.27002 ],<br />
# [1030.52002 ],<br />
# [1033.98999 ],<br />
# [1026.459961],<br />
# [1023.419983],<br />
# [1022.590027],<br />
# [1019.210022],<br />
# [1022.52002 ],<br />
# [1034.01001 ],<br />
# [1020.26001 ],<br />
# [1023.309998],<br />
# [1035. ],<br />
# [1035.869995],<br />
# [1040. ],<br />
# [1055.089966],<br />
# [1042.680054],<br />
# [1022.369995],<br />
# [1015.799988],<br />
# [1012.659973],<br />
# [ 995.940002],<br />
# [1001.5 ],<br />
# [1020.429993],<br />
# [1037.48999 ],<br />
# [1035.5 ],<br />
# [1039.630005],<br />
# [1046.119995],<br />
# [1045. ],<br />
# [1054.609985],<br />
# [1066.079956],</p>
# </blockquote>
# <p>https://colab.research.google.com/drive/1vNpD80L3kJ6r1xGYeyYTMS2hItp4ZvIc</p></th>
# <th><p><img
# src="attachment:vertopal_9c25606b7988456e932b5da7ae04e8c9/media/image5.png"
# style="width:0.16667in;height:6.38889in" /></p>
# <p>5/7</p></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# | 4/27/23, 9:45 PM | DL4_B213021_GoogleStock.ipynb - Colaboratory | <img
#                                                                    src="attachment:vertopal_9c25606b7988456e932b5da7ae04e8c9/media/image6.png"
#                                                                    style="width:0.16667in;height:0.77778in" />                                  |
# |------------------------|------------------------|------------------------|
# | \[1075.199951\], |                                              |                                                                             |
# | \[1071.780029\], |                                              |                                                                             |
# | \[1064.949951\], |                                              |                                                                             |
# | \[1061.109985\], |                                              |                                                                             |
# | \[1058.069946\], |                                              |                                                                             |
# | \[1057.390015\], |                                              |                                                                             |
#
# > inputs = sc.transform(inputs)
# > inputs.shape
# >
# > (185, 1)
# >
# > x_test = \[\]
# > for i in range(60,185):
# > x_test.append(inputs\[i-60:i,0\])
# >
# > x_test = np.array(x_test)
# > x_test.shape
# >
# > (125, 60)
# >
# > x_test = np.reshape(x_test, (x_test.shape\[0\],x_test.shape\[1\],1))
# > x_test.shape
# >
# > (125, 60, 1)
# >
# > predicted_price = regressor.predict(x_test)
# >
# > predicted_price = sc.inverse_transform(predicted_price)
# > predicted_price
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>array([[1060.9669],<br />
# [1059.5607],<br />
# [1062.1382],<br />
# [1071.1857],<br />
# [1082.9843],<br />
# [1093.968 ],<br />
# [1102.4915],<br />
# [1105.2302],<br />
# [1105.4479],<br />
# [1104.4875],<br />
# [1109.0391],<br />
# [1115.7694],<br />
# [1122.3834],<br />
# [1127.2605],<br />
# [1131.0854],<br />
# [1137.9117],<br />
# [1148.776 ],<br />
# [1158.4279],<br />
# [1164.7532],<br />
# [1168.0515],<br />
# [1167.8665],<br />
# [1166.7338],<br />
# [1164.827 ],<br />
# [1156.1555],<br />
# [1139.8356],<br />
# [1112.7017],<br />
# [1094.9691],<br />
# [1086.4697],<br />
# [1077.6523],<br />
# [1073.6385],<br />
# [1073.5703],<br />
# [1075.4775],<br />
# [1082.2805],<br />
# [1091.726 ],<br />
# [1099.5087],<br />
# [1106.0602],<br />
# [1111.9424],<br />
# [1115.2893],<br />
# [1118.7892],<br />
# [1124.5618],<br />
# [1127.3087],<br />
# [1124.2736],<br />
# [1109.1582],<br />
# [1094.2224],<br />
# [1090.1523],<br />
# [1093.2799],<br />
# [1103.134 ],<br />
# [1117.746 ],<br />
# [1135.7585],<br />
# [1151.6923],<br />
# [1156.9574],<br />
# [1154.9141],<br />
# [1151.2883],</p>
# </blockquote>
# <p>https://colab.research.google.com/drive/1vNpD80L3kJ6r1xGYeyYTMS2hItp4ZvIc</p></th>
# <th><p><img
# src="attachment:vertopal_9c25606b7988456e932b5da7ae04e8c9/media/image7.png"
# style="width:0.16667in;height:6.55556in" /></p>
# <p>6/7</p></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# <img
# src="attachment:vertopal_9c25606b7988456e932b5da7ae04e8c9/media/image10.png"
# style="width:2.77361in;height:1.93249in" /><img
# src="attachment:vertopal_9c25606b7988456e932b5da7ae04e8c9/media/image11.png"
# style="width:2.22222in;height:1.44444in" />
#
# | 4/27/23, 9:45 PM | DL4_B213021_GoogleStock.ipynb - Colaboratory | <img
#                                                                    src="attachment:vertopal_9c25606b7988456e932b5da7ae04e8c9/media/image8.png"
#                                                                    style="width:0.16667in;height:0.61111in" />                                  |
# |------------------------|------------------------|------------------------|
# | \[1142.9575\],   |                                              |                                                                             |
# | \[1130.1636\],   |                                              |                                                                             |
# | \[1117.4648\],   |                                              |                                                                             |
# | \[1107.2164\],   |                                              |                                                                             |
# | \[1095 2411\]    |                                              |                                                                             |
#
# > plt.plot(real_stock_price,color = 'red', label = 'Real Price')
# > plt.plot(predicted_price, color = 'blue', label = 'Predicted Price')
# > plt.title('Google Stock Price Prediction')
# > plt.xlabel('Time')
# > plt.ylabel('Google Stock Price')
# > plt.legend()
# > plt.show()
#
# <img
# src="attachment:vertopal_9c25606b7988456e932b5da7ae04e8c9/media/image9.png"
# style="width:0.25in" />
#
# | https://colab.research.google.com/drive/1vNpD80L3kJ6r1xGYeyYTMS2hItp4ZvIc | 7/7 |
# |------------------------------------|------------------------------------|
